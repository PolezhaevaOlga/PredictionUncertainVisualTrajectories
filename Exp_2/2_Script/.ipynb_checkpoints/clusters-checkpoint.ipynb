# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import seaborn as sns
import matplotlib.pyplot as plt
# import scikitlearn

# %%
data = pd.read_csv("C:\\Users\\USER\\Desktop\\Paris Saclay\\These\\4_DATA\\data_exp_1a\\data_clean\\all_subject_exp_1a_ANOVA.csv", sep = ';')

# %%
data
# Out:
#     subj  NOT_EQUAL_5 as_ms  EQUAL_5 as_ms  NOT_EQUAL_15 as_ms  \
# 0      0               0.32           0.82                0.24
# 1      1               0.26           0.52                0.20
# 2      2               0.36           0.30                0.16
# 3      3               0.12           0.56                0.22
# 4      4               0.44           0.66                0.32
# 5      5               0.28           0.74                0.26
# 6      6               0.38           0.58                0.34
# 7      7               0.28           0.52                0.26
# 8      8               0.36           0.58                0.10
# 9      9               0.28           0.58                0.28
# 10    10               0.28           0.62                0.18
# 11    11               0.14           0.68                0.26
# 12    12               0.24           0.28                0.22
# 13    13               0.30           0.44                0.28
# 14    14               0.20           0.56                0.30
# 15    15               0.58           0.76                0.36
# 16    16               0.30           0.50                0.24
# 17    17               0.38           0.54                0.30
# 18    18               0.46           0.62                0.38
# 19    19               0.24           0.58                0.24
# 20    20               0.44           0.56                0.28
# 21    21               0.38           0.44                0.20
#
#     EQUAL_15 as_ms  NOT_EQUAL_5 as_last  EQUAL_5 as_last  \
# 0             0.64                 0.68             0.82
# 1             0.40                 0.74             0.52
# 2             0.52                 0.64             0.30
# 3             0.72                 0.88             0.56
# 4             0.68                 0.56             0.66
# 5             0.66                 0.72             0.74
# 6             0.44                 0.62             0.58
# 7             0.32                 0.72             0.52
# 8             0.68                 0.64             0.58
# 9             0.56                 0.72             0.58
# 10            0.66                 0.72             0.62
# 11            0.56                 0.84             0.68
# 12            0.22                 0.76             0.28
# 13            0.36                 0.70             0.44
# 14            0.56                 0.80             0.56
# 15            0.66                 0.42             0.76
# 16            0.70                 0.70             0.50
# 17            0.56                 0.62             0.54
# 18            0.70                 0.54             0.62
# 19            0.44                 0.76             0.58
# 20            0.48                 0.56             0.56
# 21            0.58                 0.62             0.44
#
#     NOT_EQUAL_15 as_last  EQUAL_15 as_last  NOT_EQUAL_5 RT  EQUAL_5 RT  \
# 0                   0.76              0.64         0.66882     0.71294
# 1                   0.80              0.40         0.64921     0.71535
# 2                   0.84              0.52         0.96102     0.97074
# 3                   0.78              0.72         0.72334     0.78798
# 4                   0.68              0.68         0.95696     0.73302
# 5                   0.74              0.66         0.55035     0.53679
# 6                   0.66              0.44         0.57996     0.59408
# 7                   0.74              0.32         0.65390     0.61888
# 8                   0.90              0.68         0.68965     0.85772
# 9                   0.72              0.56         0.62720     0.60317
# 10                  0.82              0.66         0.58584     0.61609
# 11                  0.74              0.56         0.56494     0.66432
# 12                  0.78              0.22         0.60978     0.71830
# 13                  0.72              0.36         0.61794     0.68429
# 14                  0.70              0.56         1.05486     1.04672
# 15                  0.64              0.66         0.85961     0.85426
# 16                  0.76              0.70         0.95052     1.04046
# 17                  0.70              0.56         0.75628     0.76390
# 18                  0.62              0.70         0.63162     0.63318
# 19                  0.76              0.44         0.65654     0.71446
# 20                  0.72              0.48         0.61134     0.57959
# 21                  0.80              0.58         0.63246     0.67590
#
#     NOT_EQUAL_15 RT  EQUAL_15 RT  NOT_EQUAL_5 Acc  EQUAL_5 Acc  \
# 0           0.66976      0.72355             0.68         0.82
# 1           0.68435      0.81222             0.74         0.52
# 2           1.04182      1.04128             0.64         0.30
# 3           0.64982      0.65327             0.88         0.56
# 4           0.80236      0.74915             0.56         0.66
# 5           0.55547      0.54301             0.72         0.74
# 6           0.59516      0.64430             0.62         0.58
# 7           0.63462      0.63130             0.72         0.52
# 8           0.69998      0.87053             0.64         0.58
# 9           0.73022      0.67843             0.72         0.58
# 10          0.59300      0.58359             0.72         0.62
# 11          0.64966      0.82127             0.84         0.68
# 12          0.63840      0.70428             0.76         0.28
# 13          0.54098      0.58557             0.70         0.44
# 14          0.97896      1.02584             0.80         0.56
# 15          0.80129      0.82022             0.42         0.76
# 16          1.03379      1.19738             0.70         0.50
# 17          0.68062      0.81602             0.62         0.54
# 18          0.57974      0.62900             0.54         0.62
# 19          0.73231      0.79110             0.76         0.58
# 20          0.62882      0.59068             0.56         0.56
# 21          0.57810      0.60726             0.62         0.44
#
#     NOT_EQUAL_15 Acc  EQUAL_15 Acc
# 0               0.76          0.64
# 1               0.80          0.40
# 2               0.84          0.52
# 3               0.78          0.72
# 4               0.68          0.68
# 5               0.74          0.66
# 6               0.66          0.44
# 7               0.74          0.32
# 8               0.90          0.68
# 9               0.72          0.56
# 10              0.82          0.66
# 11              0.74          0.56
# 12              0.78          0.22
# 13              0.72          0.36
# 14              0.70          0.56
# 15              0.64          0.66
# 16              0.76          0.70
# 17              0.70          0.56
# 18              0.62          0.70
# 19              0.76          0.44
# 20              0.72          0.48
# 21              0.80          0.58

# %%
distortions = []
K = range(1, 10)
for k in K:
    kmeanModel = KMeans(n_clusters=k, random_state=0)
    kmeanModel.fit(data.iloc[:, 1:5])  # Fit the model to the features only
    distortions.append(kmeanModel.inertia_)

# Plotting the Elbow graph
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Distortion (Inertia)')
plt.title('The Elbow Method showing the optimal k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7216\1206326779.py in <module>
#       3 for k in K:
#       4     kmeanModel = KMeans(n_clusters=k, random_state=0)
# ----> 5     kmeanModel.fit(data.iloc[:, 1:5])  # Fit the model to the features only
#       6     distortions.append(kmeanModel.inertia_)
#       7
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1169         if self._algorithm == "full":
#    1170             kmeans_single = _kmeans_single_lloyd
# -> 1171             self._check_mkl_vcomp(X, X.shape[0])
#    1172         else:
#    1173             kmeans_single = _kmeans_single_elkan
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _check_mkl_vcomp(self, X, n_samples)
#    1026         active_threads = int(np.ceil(n_samples / CHUNK_SIZE))
#    1027         if active_threads < self._n_threads:
# -> 1028             modules = threadpool_info()
#    1029             has_vcomp = "vcomp" in [module["prefix"] for module in modules]
#    1030             has_mkl = ("mkl", "intel") in [
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in threadpool_info()
#     323         return controller.info()
#     324     else:
# --> 325         return threadpoolctl.threadpool_info()
#     326
#     327
#
# ~\anaconda3\lib\site-packages\threadpoolctl.py in threadpool_info()
#     122     In addition, each module may contain internal_api specific entries.
#     123     """
# --> 124     return _ThreadpoolInfo(user_api=_ALL_USER_APIS).todicts()
#     125
#     126
#
# ~\anaconda3\lib\site-packages\threadpoolctl.py in __init__(self, user_api, prefixes, modules)
#     338
#     339             self.modules = []
# --> 340             self._load_modules()
#     341             self._warn_if_incompatible_openmp()
#     342         else:
#
# ~\anaconda3\lib\site-packages\threadpoolctl.py in _load_modules(self)
#     371             self._find_modules_with_dyld()
#     372         elif sys.platform == "win32":
# --> 373             self._find_modules_with_enum_process_module_ex()
#     374         else:
#     375             self._find_modules_with_dl_iterate_phdr()
#
# ~\anaconda3\lib\site-packages\threadpoolctl.py in _find_modules_with_enum_process_module_ex(self)
#     483
#     484                 # Store the module if it is supported and selected
# --> 485                 self._make_module_from_path(filepath)
#     486         finally:
#     487             kernel_32.CloseHandle(h_process)
#
# ~\anaconda3\lib\site-packages\threadpoolctl.py in _make_module_from_path(self, filepath)
#     513             if prefix in self.prefixes or user_api in self.user_api:
#     514                 module_class = globals()[module_class]
# --> 515                 module = module_class(filepath, prefix, user_api, internal_api)
#     516                 self.modules.append(module)
#     517
#
# ~\anaconda3\lib\site-packages\threadpoolctl.py in __init__(self, filepath, prefix, user_api, internal_api)
#     604         self.internal_api = internal_api
#     605         self._dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
# --> 606         self.version = self.get_version()
#     607         self.num_threads = self.get_num_threads()
#     608         self._get_extra_info()
#
# ~\anaconda3\lib\site-packages\threadpoolctl.py in get_version(self)
#     644                              lambda: None)
#     645         get_config.restype = ctypes.c_char_p
# --> 646         config = get_config().split()
#     647         if config[0] == b"OpenBLAS":
#     648             return config[1].decode("utf-8")
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
data_as_ms = data[['EQUAL_5 as_ms','EQUAL_15 as_ms','NOT_EQUAL_5 as_ms','NOT_EQUAL_15 as_ms']]   
data_as_ms
# Out:
#     EQUAL_5 as_ms  EQUAL_15 as_ms  NOT_EQUAL_5 as_ms  NOT_EQUAL_15 as_ms
# 0            0.82            0.64               0.32                0.24
# 1            0.52            0.40               0.26                0.20
# 2            0.30            0.52               0.36                0.16
# 3            0.56            0.72               0.12                0.22
# 4            0.66            0.68               0.44                0.32
# 5            0.74            0.66               0.28                0.26
# 6            0.58            0.44               0.38                0.34
# 7            0.52            0.32               0.28                0.26
# 8            0.58            0.68               0.36                0.10
# 9            0.58            0.56               0.28                0.28
# 10           0.62            0.66               0.28                0.18
# 11           0.68            0.56               0.14                0.26
# 12           0.28            0.22               0.24                0.22
# 13           0.44            0.36               0.30                0.28
# 14           0.56            0.56               0.20                0.30
# 15           0.76            0.66               0.58                0.36
# 16           0.50            0.70               0.30                0.24
# 17           0.54            0.56               0.38                0.30
# 18           0.62            0.70               0.46                0.38
# 19           0.58            0.44               0.24                0.24
# 20           0.56            0.48               0.44                0.28
# 21           0.44            0.58               0.38                0.20

# %%
data_as_last = data[['EQUAL_5 as_last','EQUAL_15 as_last','NOT_EQUAL_5 as_last','NOT_EQUAL_15 as_last']]   
data_as_last
# Out:
#     EQUAL_5 as_last  EQUAL_15 as_last  NOT_EQUAL_5 as_last  \
# 0              0.82              0.64                 0.68
# 1              0.52              0.40                 0.74
# 2              0.30              0.52                 0.64
# 3              0.56              0.72                 0.88
# 4              0.66              0.68                 0.56
# 5              0.74              0.66                 0.72
# 6              0.58              0.44                 0.62
# 7              0.52              0.32                 0.72
# 8              0.58              0.68                 0.64
# 9              0.58              0.56                 0.72
# 10             0.62              0.66                 0.72
# 11             0.68              0.56                 0.84
# 12             0.28              0.22                 0.76
# 13             0.44              0.36                 0.70
# 14             0.56              0.56                 0.80
# 15             0.76              0.66                 0.42
# 16             0.50              0.70                 0.70
# 17             0.54              0.56                 0.62
# 18             0.62              0.70                 0.54
# 19             0.58              0.44                 0.76
# 20             0.56              0.48                 0.56
# 21             0.44              0.58                 0.62
#
#     NOT_EQUAL_15 as_last
# 0                   0.76
# 1                   0.80
# 2                   0.84
# 3                   0.78
# 4                   0.68
# 5                   0.74
# 6                   0.66
# 7                   0.74
# 8                   0.90
# 9                   0.72
# 10                  0.82
# 11                  0.74
# 12                  0.78
# 13                  0.72
# 14                  0.70
# 15                  0.64
# 16                  0.76
# 17                  0.70
# 18                  0.62
# 19                  0.76
# 20                  0.72
# 21                  0.80

# %%
data_as_ms.iloc[:, 1:]
# Out:
#     EQUAL_15 as_ms  NOT_EQUAL_5 as_ms  NOT_EQUAL_15 as_ms
# 0             0.64               0.32                0.24
# 1             0.40               0.26                0.20
# 2             0.52               0.36                0.16
# 3             0.72               0.12                0.22
# 4             0.68               0.44                0.32
# 5             0.66               0.28                0.26
# 6             0.44               0.38                0.34
# 7             0.32               0.28                0.26
# 8             0.68               0.36                0.10
# 9             0.56               0.28                0.28
# 10            0.66               0.28                0.18
# 11            0.56               0.14                0.26
# 12            0.22               0.24                0.22
# 13            0.36               0.30                0.28
# 14            0.56               0.20                0.30
# 15            0.66               0.58                0.36
# 16            0.70               0.30                0.24
# 17            0.56               0.38                0.30
# 18            0.70               0.46                0.38
# 19            0.44               0.24                0.24
# 20            0.48               0.44                0.28
# 21            0.58               0.38                0.20

# %%
from sklearn.cluster import KMeans

k = 3

kmeans = KMeans(n_clusters=k, random_state=0).fit(data_as_ms)
# kmeans = KMeans(n_clusters=k, random_state=0).fit(data[['EQUAL_5 as_ms','EQUAL_15 as_ms']])

labels = kmeans.labels_
data_as_ms_clusters = data_as_ms.copy()
data_as_ms_clusters['cluster'] = labels

pca = PCA(n_components=2)
principal_components = pca.fit_transform(data_as_ms)

principal_df = pd.DataFrame(data=principal_components, columns=['PC_1', 'PC_2'])
principal_df['cluster'] = kmeans.labels_

sns.scatterplot(x='PC_1', y='PC_2', hue='cluster', data=principal_df, palette='viridis', )
centroids = pca.transform(kmeans.cluster_centers_)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50, marker='X')

plt.title('')
plt.show()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score


silhouette_avg = silhouette_score(data_as_ms, labels, metric='euclidean')
calinski_harabasz_index = calinski_harabasz_score(data_as_ms, labels)
davies_bouldin_index = davies_bouldin_score(data_as_ms, labels)

print(silhouette_avg, calinski_harabasz_index, davies_bouldin_index)
# Out:
# 0.24777197404705406 10.720767562171636 1.187927210792784

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
silhouette_avg = silhouette_score(data_as_ms, labels,metric = 'euclidean')
calinski_harabasz_index = calinski_harabasz_score(data_as_ms, labels)
davies_bouldin_index = davies_bouldin_score(data_as_ms, labels)
silhouette_avg,calinski_harabasz_index,davies_bouldin_index
# Out:
# (0.24777197404705406, 10.720767562171636, 1.187927210792784)

# %%
data_as_last_clusters['cluster'].to_list()
# Out:
# [0, 1, 1, 2, 0, 0, 1, 1, 2, 2, 2, 2, 1, 1, 2, 0, 2, 2, 0, 1, 1, 2]

# %%
data_as_ms_clusters['cluster'].to_list()
# Out:
# [0, 1, 1, 2, 0, 0, 1, 1, 2, 2, 2, 2, 1, 1, 2, 0, 2, 2, 0, 1, 1, 2]

# %%
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
data_2d_pca = pca.fit_transform(data)

plt.figure(figsize=(5, 5))
plt.scatter(data_2d_pca[:, 0], data_2d_pca[:, 1], c=cluster_labels, cmap='viridis', edgecolor='k')
plt.title("PCA visualization of game clusters")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# Применяем иерархическую кластеризацию
linked = linkage(data, method='average')

# Визуализация дендрограммы
plt.figure(figsize=(10, 7))
dendrogram(linked)
plt.title('Hierarchical Clustering Dendrogram')
plt.show()
