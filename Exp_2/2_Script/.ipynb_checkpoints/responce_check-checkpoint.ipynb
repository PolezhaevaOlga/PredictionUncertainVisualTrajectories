# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import pandas as pd
import scipy
from scipy.optimize import minimize
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import linregress
import statsmodels.api as sm

# %%
iid_equal = pd.read_csv('all_subject_equal.csv',sep ="\t", header=0)
iid_n_equal = pd.read_csv('all_subject_n_equal.csv',sep ="\t", header=0)

# %%
iid_n_equal.columns
# Out:
# Index(['# subj', 'trial', 'index_traj', 'path', 'last_cond', 'condition',
#        'index_old', 'mean_side', 'mean_val', 'mean_last5', 'mean_last15', 'sd',
#        'last_visibl_side', 'f_missing_pos', 'last_visibl_center_dist[deg]',
#        'response', 'RT', 'prop_last_5', 'prop_last_15', 'prop_ms', 'prop_lv',
#        'accuracy'],
#       dtype='object')

# %%
def path_responces (path):
    grouped_data = path.groupby(['index_traj', 'condition', 'mean_side']).agg(
    path=pd.NamedAgg(column='path', aggfunc='first'),
    last_cond=pd.NamedAgg(column='last_cond', aggfunc='first'),
    index_old=pd.NamedAgg(column='index_old', aggfunc='first'),
    mean_val=pd.NamedAgg(column='mean_val', aggfunc='first'),
    mean_last5=pd.NamedAgg(column='mean_last5', aggfunc='first'),
    mean_last15=pd.NamedAgg(column='mean_last15', aggfunc='first'),
    sd=pd.NamedAgg(column='sd', aggfunc='first'),
    last_visibl_side=pd.NamedAgg(column='last_visibl_side', aggfunc='first'),
    f_missing_pos=pd.NamedAgg(column='f_missing_pos', aggfunc='first'),
    last_visibl_center_dist_deg=pd.NamedAgg(column='last_visibl_center_dist[deg]', aggfunc='first'),
    correct=pd.NamedAgg(column='accuracy', aggfunc=lambda x: (x == 1).sum()),
    error=pd.NamedAgg(column='accuracy', aggfunc=lambda x: (x == 0).sum()),
    acc=pd.NamedAgg(column='accuracy', aggfunc=lambda x: np.round(x.mean(), 3)),
    RT=pd.NamedAgg(column='RT', aggfunc=lambda x: np.round(x.mean(), 3))).reset_index()
    grouped_data['mean_abs'] = grouped_data['mean_val'].apply(abs)
    group_sd = []
    for sd in grouped_data['sd']:
        if sd < 3.4:
            group_sd.append(1)
        elif 3.4 <= sd < 5.3:
            group_sd.append(2)
        else:  # Assuming sd >= 5.5
            group_sd.append(3)
    grouped_data['group_sd'] = group_sd
    grouped_data['mean/std'] = round( abs(grouped_data['mean_val']/ grouped_data['sd']),3)
    # Calculating the difference between mean_abs and JND for each group
    diff_list = []
    # jnd_values = {1: 0.386, 2: 0.581, 3: 0.654}
    # jnd_values = {1: 1.3, 2: 1.3, 3: 1.3}
    jnd_values = {1: 0.6, 2: 0.9, 3: 1.3}
    for i in range(grouped_data.shape[0]):
        group = grouped_data['group_sd'][i]
        jnd = jnd_values[group]
    #     diff = round(abs(grouped_data['mean_abs'][i] - jnd), 3)
        diff = round(grouped_data['mean_abs'][i] - jnd, 3)
        diff_list.append(diff)

    grouped_data['mu-jnd'] = diff_list

    return grouped_data

# %%
grouped_iid_n_equal=path_responces (iid_n_equal)
grouped_iid_equal=path_responces (iid_equal)
grouped_iid_n_equal
# Out:
#     index_traj    condition mean_side path last_cond  index_old  mean_val  \
# 0            0  opposite_15      left  15%  opposite          1    -0.775
# 1            0  opposite_15     right  15%  opposite          1     0.775
# 2            0   opposite_5      left   5%  opposite          1    -0.775
# 3            0   opposite_5     right   5%  opposite          1     0.775
# 4            1  opposite_15      left  15%  opposite          6    -0.931
# ..         ...          ...       ...  ...       ...        ...       ...
# 95          23   opposite_5     right   5%  opposite         48     0.888
# 96          24  opposite_15      left  15%  opposite         49    -1.143
# 97          24  opposite_15     right  15%  opposite         49     1.143
# 98          24   opposite_5      left   5%  opposite         49    -1.143
# 99          24   opposite_5     right   5%  opposite         49     1.143
#
#     mean_last5  mean_last15     sd  ... f_missing_pos  \
# 0        0.834        0.640  2.342  ...             4
# 1       -0.834       -0.640  2.342  ...             4
# 2        0.767       -0.159  2.342  ...             4
# 3       -0.767        0.159  2.342  ...             4
# 4        1.006        0.838  2.989  ...             8
# ..         ...          ...    ...  ...           ...
# 95      -0.941        1.395  6.245  ...            38
# 96       1.208        1.073  6.283  ...            39
# 97      -1.208       -1.073  6.283  ...            39
# 98       1.239       -3.393  6.283  ...            39
# 99      -1.239        3.393  6.283  ...            39
#
#     last_visibl_center_dist_deg  correct  error    acc     RT  mean_abs  \
# 0                         3.749       20      2  0.909  0.578     0.775
# 1                        -3.749       22      0  1.000  0.606     0.775
# 2                         3.749       19      3  0.864  0.638     0.775
# 3                        -3.749       16      6  0.727  0.691     0.775
# 4                         5.179       16      6  0.727  0.588     0.931
# ..                          ...      ...    ...    ...    ...       ...
# 95                       -8.275       12     10  0.545  0.760     0.888
# 96                        3.668       14      8  0.636  0.794     1.143
# 97                       -3.668       12     10  0.545  0.730     1.143
# 98                        3.668       18      4  0.818  0.689     1.143
# 99                       -3.668       19      3  0.864  0.774     1.143
#
#     group_sd  mean/std  mu-jnd
# 0          1     0.331   0.175
# 1          1     0.331   0.175
# 2          1     0.331   0.175
# 3          1     0.331   0.175
# 4          1     0.311   0.331
# ..       ...       ...     ...
# 95         3     0.142  -0.412
# 96         3     0.182  -0.157
# 97         3     0.182  -0.157
# 98         3     0.182  -0.157
# 99         3     0.182  -0.157
#
# [100 rows x 21 columns]

# %%
def make_LR_mu_std(grouped_data):
    models = []

    grouped = grouped_data.groupby(['path',])

    for group_name, group_data in grouped:
        X = sm.add_constant(group_data['mean/std'])  
        y = group_data['acc']  
        model = sm.OLS(y, X).fit()  
        models.append((group_name, model))  

    for group_name, model in models:
        print(f"Group : {group_name}, {grouped_data['last_cond']}")
        print(model.summary())
        print("\n")
    return models

# %%
models_n_equal = make_LR_mu_std(grouped_iid_n_equal)
models_equal = make_LR_mu_std(grouped_iid_equal)
# Out:
# Group : ('15%',), 0     opposite
# 1     opposite
# 2     opposite
# 3     opposite
# 4     opposite
#         ...
# 95    opposite
# 96    opposite
# 97    opposite
# 98    opposite
# 99    opposite
# Name: last_cond, Length: 100, dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    acc   R-squared:                       0.223
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     13.75
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):           0.000542
# Time:                        13:03:28   Log-Likelihood:                 25.328
# No. Observations:                  50   AIC:                            -46.66
# Df Residuals:                      48   BIC:                            -42.83
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4838      0.073      6.589      0.000       0.336       0.631
# mean/std       0.9828      0.265      3.708      0.001       0.450       1.516
# ==============================================================================
# Omnibus:                        1.066   Durbin-Watson:                   1.745
# Prob(Omnibus):                  0.587   Jarque-Bera (JB):                0.960
# Skew:                          -0.325   Prob(JB):                        0.619
# Kurtosis:                       2.807   Cond. No.                         13.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Group : ('5%',), 0     opposite
# 1     opposite
# 2     opposite
# 3     opposite
# 4     opposite
#         ...
# 95    opposite
# 96    opposite
# 97    opposite
# 98    opposite
# 99    opposite
# Name: last_cond, Length: 100, dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    acc   R-squared:                       0.247
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     15.77
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):           0.000239
# Time:                        13:03:28   Log-Likelihood:                 23.802
# No. Observations:                  50   AIC:                            -43.60
# Df Residuals:                      48   BIC:                            -39.78
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3920      0.076      5.178      0.000       0.240       0.544
# mean/std       1.0853      0.273      3.972      0.000       0.536       1.635
# ==============================================================================
# Omnibus:                        6.340   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                5.535
# Skew:                          -0.589   Prob(JB):                       0.0628
# Kurtosis:                       4.127   Cond. No.                         13.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Group : ('15%',), 0     same
# 1     same
# 2     same
# 3     same
# 4     same
#       ...
# 95    same
# 96    same
# 97    same
# 98    same
# 99    same
# Name: last_cond, Length: 100, dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    acc   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.6488
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):              0.425
# Time:                        13:03:28   Log-Likelihood:                 23.639
# No. Observations:                  50   AIC:                            -43.28
# Df Residuals:                      48   BIC:                            -39.45
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6078      0.075      8.093      0.000       0.457       0.759
# mean/std      -0.2145      0.266     -0.805      0.425      -0.750       0.321
# ==============================================================================
# Omnibus:                        1.728   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.421   Jarque-Bera (JB):                1.316
# Skew:                          -0.397   Prob(JB):                        0.518
# Kurtosis:                       2.996   Cond. No.                         13.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Group : ('5%',), 0     same
# 1     same
# 2     same
# 3     same
# 4     same
#       ...
# 95    same
# 96    same
# 97    same
# 98    same
# 99    same
# Name: last_cond, Length: 100, dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    acc   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.8627
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):              0.358
# Time:                        13:03:28   Log-Likelihood:                 29.352
# No. Observations:                  50   AIC:                            -54.70
# Df Residuals:                      48   BIC:                            -50.88
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6257      0.068      9.236      0.000       0.490       0.762
# mean/std      -0.2272      0.245     -0.929      0.358      -0.719       0.265
# ==============================================================================
# Omnibus:                        3.632   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.163   Jarque-Bera (JB):                2.660
# Skew:                          -0.411   Prob(JB):                        0.264
# Kurtosis:                       2.224   Cond. No.                         13.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
def make_LR(grouped_data):
    models = []

    grouped = grouped_data.groupby(['path',])

    for group_name, group_data in grouped:
        X = sm.add_constant(group_data['mu-jnd'])  
        y = group_data['acc']  
        model = sm.OLS(y, X).fit()  
        models.append((group_name, model))  

    for group_name, model in models:
        print(f"Group : {group_name}, {grouped_data['last_cond']}")
        print(model.summary())
        print("\n")
    return models

# %%
models_n_equal = make_LR(grouped_iid_n_equal)
models_n_equal = make_LR(grouped_iid_equal)
# Out:
# Group : ('15%',), 0     opposite
# 1     opposite
# 2     opposite
# 3     opposite
# 4     opposite
#         ...
# 95    opposite
# 96    opposite
# 97    opposite
# 98    opposite
# 99    opposite
# Name: last_cond, Length: 100, dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    acc   R-squared:                       0.188
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     11.13
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):            0.00165
# Time:                        13:03:32   Log-Likelihood:                 24.244
# No. Observations:                  50   AIC:                            -44.49
# Df Residuals:                      48   BIC:                            -40.66
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7047      0.025     28.628      0.000       0.655       0.754
# mu-jnd         0.1847      0.055      3.336      0.002       0.073       0.296
# ==============================================================================
# Omnibus:                        1.257   Durbin-Watson:                   1.657
# Prob(Omnibus):                  0.533   Jarque-Bera (JB):                1.197
# Skew:                          -0.242   Prob(JB):                        0.550
# Kurtosis:                       2.417   Cond. No.                         2.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Group : ('5%',), 0     opposite
# 1     opposite
# 2     opposite
# 3     opposite
# 4     opposite
#         ...
# 95    opposite
# 96    opposite
# 97    opposite
# 98    opposite
# 99    opposite
# Name: last_cond, Length: 100, dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    acc   R-squared:                       0.123
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     6.714
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):             0.0126
# Time:                        13:03:32   Log-Likelihood:                 19.972
# No. Observations:                  50   AIC:                            -35.94
# Df Residuals:                      48   BIC:                            -32.12
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6462      0.027     24.105      0.000       0.592       0.700
# mu-jnd         0.1563      0.060      2.591      0.013       0.035       0.278
# ==============================================================================
# Omnibus:                        2.233   Durbin-Watson:                   1.539
# Prob(Omnibus):                  0.327   Jarque-Bera (JB):                1.496
# Skew:                          -0.407   Prob(JB):                        0.473
# Kurtosis:                       3.232   Cond. No.                         2.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Group : ('15%',), 0     same
# 1     same
# 2     same
# 3     same
# 4     same
#       ...
# 95    same
# 96    same
# 97    same
# 98    same
# 99    same
# Name: last_cond, Length: 100, dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    acc   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.4449
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):              0.508
# Time:                        13:03:32   Log-Likelihood:                 23.534
# No. Observations:                  50   AIC:                            -43.07
# Df Residuals:                      48   BIC:                            -39.24
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5583      0.025     22.138      0.000       0.508       0.609
# mu-jnd        -0.0358      0.054     -0.667      0.508      -0.144       0.072
# ==============================================================================
# Omnibus:                        1.654   Durbin-Watson:                   1.766
# Prob(Omnibus):                  0.437   Jarque-Bera (JB):                1.216
# Skew:                          -0.382   Prob(JB):                        0.544
# Kurtosis:                       3.024   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Group : ('5%',), 0     same
# 1     same
# 2     same
# 3     same
# 4     same
#       ...
# 95    same
# 96    same
# 97    same
# 98    same
# 99    same
# Name: last_cond, Length: 100, dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    acc   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.195
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):              0.280
# Time:                        13:03:32   Log-Likelihood:                 29.522
# No. Observations:                  50   AIC:                            -55.04
# Df Residuals:                      48   BIC:                            -51.22
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5772      0.022     26.061      0.000       0.533       0.622
# mu-jnd        -0.0545      0.050     -1.093      0.280      -0.155       0.046
# ==============================================================================
# Omnibus:                        3.997   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.136   Jarque-Bera (JB):                2.972
# Skew:                          -0.452   Prob(JB):                        0.226
# Kurtosis:                       2.220   Cond. No.                         2.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
def plotting (grouped_data_1,grouped_data_2):
#     plt.subplot(1,1,1)
    sns.lmplot(x='mu-jnd',
           y='acc',
           data=grouped_data_1,
           hue='path',
           ci=None,
           scatter_kws={'alpha': 0.5})
    plt.title('IID EQUAL: mu-jnd vs acc ')
    plt.xlabel('mu-jnd difference')
    plt.ylabel('mean acc')
    # Linear regression by mean_cond groups
    linear_regression_by_group = grouped_data_1.groupby('path').apply(
        lambda group: linregress(group['mu-jnd'], group['acc']))
    print("IID EQUAL:")
    for group, result in zip(linear_regression_by_group.index,
                             linear_regression_by_group):
        slope, intercept, r_value, p_value, std_err = result
        
        print(
            f"Group: {group}, Slope = {round(slope,3)}, Intercept = {round(intercept,3)}, $R^2$={r_value**2:.2f}, P-value = {round(p_value,3)}, Std_err = {round(std_err,3)}"
        )
    sns.lmplot(x='mu-jnd',
           y='acc',
           data=grouped_data_2,
           hue='path',
           ci=None,
           scatter_kws={'alpha': 0.5})
    plt.title('IID NOT EQUAL: mu-jnd vs acc ')
    plt.xlabel('mu-jnd difference')
    plt.ylabel('mean acc')
    # Linear regression by mean_cond groups
    linear_regression_by_group = grouped_data_2.groupby('path').apply(
        lambda group: linregress(group['mu-jnd'], group['acc']))
    print("IID NOT EQUAL:")
    for group, result in zip(linear_regression_by_group.index,
                             linear_regression_by_group):
        slope, intercept, r_value, p_value, std_err = result
        
        print(
            f"Group: {group}, Slope = {round(slope,3)}, Intercept = {round(intercept,3)}, $R^2$={r_value**2:.2f}, P-value = {round(p_value,3)}, Std_err = {round(std_err,3)}"
        )

# %%
plotting (grouped_iid_equal,grouped_iid_n_equal)
# Out:
# IID EQUAL:
# Group: 15%, Slope = -0.036, Intercept = 0.558, $R^2$=0.01, P-value = 0.508, Std_err = 0.054
# Group: 5%, Slope = -0.054, Intercept = 0.577, $R^2$=0.02, P-value = 0.28, Std_err = 0.05
# IID NOT EQUAL:
# Group: 15%, Slope = 0.185, Intercept = 0.705, $R^2$=0.19, P-value = 0.002, Std_err = 0.055
# Group: 5%, Slope = 0.156, Intercept = 0.646, $R^2$=0.12, P-value = 0.013, Std_err = 0.06

# %%
# Scatter plot with regression line
sns.lmplot(x='mean/std', y='acc', data=grouped_iid_equal, ci=None, scatter_kws={'alpha':0.5})
plt.title('IID EQUAL: mean/std vs acc')
plt.xlabel('mean/std')
plt.ylabel('acc ')
plt.show()

slope, intercept, r_value, p_value, std_err = linregress(grouped_iid_equal['mean/std'], grouped_iid_equal['acc'])
print(f"IID EQUAL: slope = {round(slope,3)}, intercept = {round(intercept,3)}, r_value = {round(r_value,3)}, p_value = {round(p_value,3)}, std_err = {round(std_err,3)}")

sns.lmplot(x='mean/std', y='acc', data=grouped_iid_n_equal, ci=None, scatter_kws={'alpha':0.5})
plt.title('IID NOT EQUAL: mu-jndvs acc')
plt.xlabel('mean/std')
plt.ylabel('acc ')
plt.show()

slope, intercept, r_value, p_value, std_err = linregress(grouped_iid_n_equal['mean/std'], grouped_iid_n_equal['acc'])
print(f"IID NOT EQUAL: slope = {round(slope,3)}, intercept = {round(intercept,3)}, r_value = {round(r_value,3)}, p_value = {round(p_value,3)}, std_err = {round(std_err,3)}")
# Out:
# IID EQUAL: slope = -0.223, intercept = 0.617, r_value = -0.125, p_value = 0.216, std_err = 0.179
# IID NOT EQUAL: slope = 1.034, intercept = 0.438, r_value = 0.476, p_value = 0.0, std_err = 0.193
